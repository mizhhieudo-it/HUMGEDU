-- %% [markdown]
-- # [dbo].[baihoc]

-- %%
USE [HUMGEDU]
GO

-- %%
/****** Object:  Table [dbo].[baihoc]    Script Date: 9/11/2021 1:39:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[baihoc](
	[idbaihoc] [int] IDENTITY(1,1) NOT NULL,
	[tenbaihoc] [text] NULL,
	[motabaihoc] [text] NULL,
	[linkvideobaihoc] [text] NULL,
	[linkbaihoc] [text] NULL,
 CONSTRAINT [PK_baihoc] PRIMARY KEY CLUSTERED 
(
	[idbaihoc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[danhmuc]

-- %%
/****** Object:  Table [dbo].[danhmuc]    Script Date: 9/11/2021 1:39:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[danhmuc](
	[iddanhmuc] [int] IDENTITY(1,1) NOT NULL,
	[tendanhmuc] [nvarchar](250) NOT NULL,
	[linkdanhmuc] [nvarchar](max) NOT NULL,
	[idkhoahoc] [int] NOT NULL,
 CONSTRAINT [PK_danhmuc] PRIMARY KEY CLUSTERED 
(
	[iddanhmuc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[khoahoc]

-- %%
/****** Object:  Table [dbo].[khoahoc]    Script Date: 9/11/2021 1:39:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[khoahoc](
	[idkhoahoc] [int] NOT NULL,
	[tenkhoahoc] [nvarchar](250) NOT NULL,
	[linkkhoahoc] [nvarchar](max) NOT NULL,
	[motakhoahoc] [nvarchar](max) NOT NULL,
	[anhmotakhoahoc] [text] NOT NULL,
	[idbaihoc] [int] NOT NULL,
 CONSTRAINT [PK_khoahoc] PRIMARY KEY CLUSTERED 
(
	[idkhoahoc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[taikhoan]

-- %%
/****** Object:  Table [dbo].[taikhoan]    Script Date: 9/11/2021 1:39:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[taikhoan](
	[iduser] [int] IDENTITY(1,1) NOT NULL,
	[username] [nvarchar](50) NULL,
	[password] [nvarchar](50) NULL,
	[mail] [nvarchar](100) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[thongbao]

-- %%
/****** Object:  Table [dbo].[thongbao]    Script Date: 9/11/2021 1:39:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[thongbao](
	[idthongbao] [int] IDENTITY(1,1) NOT NULL,
	[motathongbao] [text] NULL,
	[linkthongbao] [text] NULL,
 CONSTRAINT [PK_thongbao] PRIMARY KEY CLUSTERED 
(
	[idthongbao] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_danhmuc_khoahoc]

-- %%
ALTER TABLE [dbo].[danhmuc]  WITH CHECK ADD  CONSTRAINT [FK_danhmuc_khoahoc] FOREIGN KEY([idkhoahoc])
REFERENCES [dbo].[khoahoc] ([idkhoahoc])
GO
ALTER TABLE [dbo].[danhmuc] CHECK CONSTRAINT [FK_danhmuc_khoahoc]
GO

-- %% [markdown]
-- # [FK_khoahoc_baihoc]

-- %%
ALTER TABLE [dbo].[khoahoc]  WITH CHECK ADD  CONSTRAINT [FK_khoahoc_baihoc] FOREIGN KEY([idbaihoc])
REFERENCES [dbo].[baihoc] ([idbaihoc])
GO
ALTER TABLE [dbo].[khoahoc] CHECK CONSTRAINT [FK_khoahoc_baihoc]
GO
